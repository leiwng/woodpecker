# %%
import itertools
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
ori_img = cv2.imread('D:\\labTable\\jinxin\\330_02\\png960x960\\20220043.016.A.png')
rep_img = cv2.imread('D:\\labTable\\jinxin\\330_02\\png960x960\\20220043.016.K.png')
plt.rcParams['figure.dpi'] = 400
plt.subplot(1, 2, 1)
plt.title('ori')
plt.imshow(ori_img)

plt.subplot(1, 2, 2)
plt.title('rep')
plt.imshow(rep_img)
